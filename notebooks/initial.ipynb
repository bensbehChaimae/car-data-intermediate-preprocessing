# %% [markdown]
# # Table of content :

# %% [markdown]
# # 1. Problem statment :

# %% [markdown]
# The goal is to develop a Machine Learning model that accurately predicts the price of a car based on various features such as brand, condition, mileage, fuel type, transmission, year, and other relevant attributes.
#
# This model aims to assist users in estimating fair car prices and making informed buying or selling decisions.

# %% [markdown]
# # 2. Data collection :

# %% [markdown]
# The dataset was collected through web scraping from two popular Moroccan car listing platforms: `moteur.ma` and `avito.ma`, ensuring a
# diverse and representative sample of used cars available in the market.

# %% [markdown]
# # 3. Data undrestanding :

# %% [markdown]
# ### Inisialize spark session :

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("PySpark Prediction model1").getOrCreate()

# Check if the Spark session is created
print(spark.version)
# Out:
# 3.5.5

# %% [markdown]
# ### Load the Data :

# %%
# Read csv file into pyspark dataFrame : 
raw_data = spark.read.csv("cleaned_data.csv",  header=True, inferSchema=True)

# %% [markdown]
# We have a problem with the categorical columns where "\NaN\" which is N/A is considered a category not a null value . Hence we should transform it to null using a python function .

# %%
from pyspark.sql.functions import col, when, regexp_replace, lit
from pyspark.sql.types import StringType

def transform_spark(df):
    for column, dtype in df.dtypes:
        if dtype == 'string':
            df = df.withColumn(
                column,
                when(
                    col(column).rlike(r'(?i)\\"nan\\"'),
                    None
                ).otherwise(col(column))
            )
    return df

# %%
# Apply the Transform function
data = transform_spark(raw_data)

# %%
# For better visualisation : 
data.limit(5).toPandas()
# Out:
#                                      id          brand  condition  \
# 0  9b006bc1-dc96-4dc0-bdd2-0c31a28d555a  mercedes-benz       None
# 1  e851563f-cac5-4703-9f50-26d10d59b89e     mitsubishi   Très bon
# 2  43e6114c-7df9-4ebf-a611-4153e866324f           fiat  Excellent
# 3  dd4a01b6-0cae-4e28-8c0f-28ee6844a823     land rover  Excellent
# 4  8c94b460-b7a4-47ba-b84c-a2e146d0e5ff          dacia  Excellent
#
#                      creator  door_count  \
# 0                    MOHAMED         NaN
# 1              Timlalin Dome         3.0
# 2  Louvre AutoShopBadge Icon         5.0
# 3             imad elmajdoub         5.0
# 4                      ayoub         5.0
#
#                                            equipment first_owner  \
# 0  Jantes aluminium, Alarme, Airbags, Abs, Vitres...        None
# 1  Airbags, Caméra de recul, Climatisation, ESP, ...         Non
# 2                 CD/MP3/Bluetooth, Jantes aluminium         Oui
# 3  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...         Oui
# 4  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...         Oui
#
#    fiscal_power fuel_type                                       image_folder  \
# 0            10    diesel                           417803_MERCEDES-BENZ_250
# 1            11    diesel                             3449_Mitsubishi_Pajero
# 2             6    diesel                             3360_Fiat_Doblo_Modèle
# 3             8    diesel  2694_لاند_روڨر_ديسكوفري_ديزل_أوتوماتيك_2017_في...
# 4             6    diesel                                   700_dacia_duster
#
#    ...      model       origin     price  publication_date      sector  \
# 0  ...        250         None   51000.0              None  Ben Guerir
# 1  ...     Pajero  WW au Maroc   85000.0  11/02/2025 00:00      Agadir
# 2  ...      Doblo  WW au Maroc       NaN  22/03/2025 00:00  Casablanca
# 3  ...  Discovery  WW au Maroc  190000.0  14/09/2024 00:00      Agadir
# 4  ...     Duster  WW au Maroc  167000.0  11/02/2025 00:00  Casablanca
#
#       seller_city  source                                             title  \
# 0       Benguerir  moteur                                MERCEDES-BENZ  250
# 1   Autre secteur   avito                                 Mitsubishi Pajero
# 2          Maarif   avito                                 Fiat Doblo Modèle
# 3       Haut Anza   avito  لاند روڨر ديسكوفري ديزل أوتوماتيك 2017 في أكادير
# 4  Sidi Bernoussi   avito                                      dacia duster
#
#   transmission  year
# 0     Manuelle  1998
# 1     Manuelle  2007
# 2     Manuelle  2021
# 3  Automatique  2017
# 4     Manuelle  2019
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Drop columns :

# %%
data = data.drop('image_folder')
data = data.drop('id')
data = data.drop('creator')
data = data.drop('title')
data = data.drop('source')

# %%
data.limit(3).toPandas()
# Out:
#            brand  condition  door_count  \
# 0  mercedes-benz       None         NaN
# 1     mitsubishi   Très bon         3.0
# 2           fiat  Excellent         5.0
#
#                                            equipment first_owner  \
# 0  Jantes aluminium, Alarme, Airbags, Abs, Vitres...        None
# 1  Airbags, Caméra de recul, Climatisation, ESP, ...         Non
# 2                 CD/MP3/Bluetooth, Jantes aluminium         Oui
#
#    fiscal_power fuel_type  mileage   model       origin    price  \
# 0            10    diesel    65000     250         None  51000.0
# 1            11    diesel   274999  Pajero  WW au Maroc  85000.0
# 2             6    diesel   104999   Doblo  WW au Maroc      NaN
#
#    publication_date      sector    seller_city transmission  year
# 0              None  Ben Guerir      Benguerir     Manuelle  1998
# 1  11/02/2025 00:00      Agadir  Autre secteur     Manuelle  2007
# 2  22/03/2025 00:00  Casablanca         Maarif     Manuelle  2021

# %% [markdown]
# ### Data Size :

# %%
# Number of rows
num_rows = data.count()

# Number of columns
num_columns = len(data.columns)

print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 60264
# Number of columns: 16

# %% [markdown]
# ### Get data schema :

# %%
# Print schema of the data
data.printSchema()
# Out:
# root
#  |-- brand: string (nullable = true)
#  |-- condition: string (nullable = true)
#  |-- door_count: integer (nullable = true)
#  |-- equipment: string (nullable = true)
#  |-- first_owner: string (nullable = true)
#  |-- fiscal_power: integer (nullable = true)
#  |-- fuel_type: string (nullable = true)
#  |-- mileage: integer (nullable = true)
#  |-- model: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- publication_date: string (nullable = true)
#  |-- sector: string (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- year: integer (nullable = true)

# %% [markdown]
# ### Categorical columns VS numerical columns :

# %% [markdown]
# | Categorical   | numerical      |
# |---------------|----------------|
# | condition     | fiscal_power   |
# | transmission  | price (target) |
# | equipment     | publication_date|
# | first_owner   | year           |
# | fuel_type     | door_count     |
# | model         | mileage        |
# | origin        |                |
# | seller_city   |                |
# | brand         |                |
# | sector        |
# | source        |

# %% [markdown]
# ______________

# %% [markdown]
# # 4.Exploratory Data Analysis (EDA) :

# %% [markdown]
# ### Unique values for each column :

# %%
# Show unique values for each column :
for col in data.columns:
    print(f"Column: {col}")
    data.select(col).distinct().show(truncate=False)
# Out:
# Column: brand
# +----------+
# |brand     |
# +----------+
# |citroën   |
# |chery     |
# |jaguar    |
# |changhe   |
# |autres    |
# |land rover|
# |ktm       |
# |daihatsu  |
# |mahindra  |
# |hummer    |
# |tata      |
# |autre     |
# |mitsubishi|
# |land-rover|
# |lexus     |
# |lada      |
# |toyota    |
# |seat      |
# |cupra     |
# |peugeot   |
# +----------+
# only showing top 20 rows
#
# Column: condition
# +-----------+
# |condition  |
# +-----------+
# |Très bon   |
# |Excellent  |
# |Correct    |
# |Neuf       |
# |Pour Pièces|
# |Endommagé  |
# |Bon        |
# |NULL       |
# +-----------+
#
# Column: door_count
# +----------+
# |door_count|
# +----------+
# |3         |
# |5         |
# |4         |
# |2         |
# |NULL      |
# +----------+
#
# Column: equipment
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |equipment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Airbags, Climatisation, Radar de recul, Vitres électriques                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |Airbags, Climatisation auto, Système de navigation / gps, Vitres éléctriques, Volant reglable, Régulateur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |Dvd / cd / mp3, Jantes aluminium, Alarme, Airbags, Aide parking, Climatisation auto, Abs, Système de navigation / gps, Carnet d'entretien, Vitres éléctriques, Anti patinage, Esp, Capote électrique, Projecteurs xenon, Rétroviseur extérieur électrique, Toit ouvrant panoramique, Toit ouvrant, Intérieur cuir, Siège chauffant, Siége electrique, Vitres surteintées, Volant reglable, Anti démarrage, Volant sport, Contrôle de pression des pneus, Détecteur de pluie, Climatisation multizone, Direction assistée, Keyless go, Ordinateur de bord, Radio commande au volant, Régulateur de vitesse, Anti brouillard, Affichage tête haute, Suspension sport, Frein de parking automatique, Non fumeur, Système d'identification du conducteur, Radar de recul, Limiteur de vitesse, Verrouillage centralisé à distance|
# |Dvd / cd / mp3, Jantes aluminium, Alarme, Airbags, Aide parking, Climatisation auto, Abs, Système de navigation / gps, Vitres éléctriques, Anti patinage, Esp, Rétroviseur extérieur électrique, Contrôle de pression des pneus, Direction assistée, Ordinateur de bord, Radio commande au volant, Régulateur de vitesse, Radar de recul, Limiteur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |Airbags, Caméra de recul, Climatisation, Jantes aluminium, Limiteur de vitesse, Radar de recul, Régulateur de vitesse, Système de navigation/GPS, Verrouillage centralisé à distance, Vitres électriques                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |CD/MP3/Bluetooth, Caméra de recul, Climatisation, Jantes aluminium, Limiteur de vitesse, Sièges cuir, Vitres électriques                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |Dvd / cd / mp3, Airbags, Vitres éléctriques, Vitres surteintées, Ordinateur de bord, Radar de recul, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |Dvd / cd / mp3, Jantes aluminium, Alarme, Airbags, Climatisation auto, Abs, Vitres éléctriques, Anti patinage, Non fumeur, Radar de recul                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |Airbags, CD/MP3/Bluetooth, Caméra de recul, Climatisation, Jantes aluminium, Radar de recul, Sièges cuir, Verrouillage centralisé à distance, Vitres électriques                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |Dvd / cd / mp3, Jantes aluminium, Alarme, Airbags, Climatisation auto, Abs, Système de navigation / gps, Carnet d'entretien, Vitres éléctriques, Anti patinage, Esp, Rétroviseur extérieur électrique, Volant reglable, Anti démarrage, Contrôle de pression des pneus, Détecteur de pluie, Climatisation multizone, Direction assistée, Ordinateur de bord, Radio commande au volant, Régulateur de vitesse, Anti brouillard, Radar de recul, Limiteur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                       |
# |ABS, Airbags, CD/MP3/Bluetooth, Caméra de recul, Climatisation, Jantes aluminium, Limiteur de vitesse, Radar de recul, Régulateur de vitesse, Sièges cuir, Toit ouvrant, Vitres électriques                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |Airbags, Climatisation, Jantes aluminium, Limiteur de vitesse, Radar de recul, Régulateur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |Dvd / cd / mp3, Jantes aluminium, Alarme, Airbags, Climatisation auto, Abs, Vitres éléctriques, Esp, Projecteurs xenon, Contrôle de pression des pneus, Détecteur de pluie, Climatisation multizone, Direction assistée, Ordinateur de bord, Régulateur de vitesse, Anti brouillard, Limiteur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |ABS, CD/MP3/Bluetooth, Jantes aluminium, Ordinateur de bord, Radar de recul, Régulateur de vitesse, Sièges cuir, Système de navigation/GPS, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |Jantes aluminium, Alarme, Airbags, Aide parking, Climatisation auto, Abs, Système de navigation / gps, Carnet d'entretien, Vitres éléctriques, Anti patinage, Esp, Projecteurs xenon, Intérieur cuir, Vitres surteintées, Volant reglable, Anti démarrage, Volant sport, Contrôle de pression des pneus, Détecteur de pluie, Climatisation multizone, Direction assistée, Ordinateur de bord, Radio commande au volant, Régulateur de vitesse, Anti brouillard, Non fumeur, Radar de recul, Limiteur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                          |
# |Dvd / cd / mp3, Jantes aluminium, Airbags, Aide parking, Climatisation auto, Abs, Système de navigation / gps, Carnet d'entretien, Vitres éléctriques, Anti patinage, Esp, Rétroviseur extérieur électrique, Siège chauffant, Siége electrique, Volant sport, Contrôle de pression des pneus, Détecteur de pluie, Radio commande au volant, Régulateur de vitesse, Anti brouillard, Suspension sport, Frein de parking automatique, Radar de recul, Limiteur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                  |
# |Jantes aluminium, Alarme, Airbags, Aide parking, Climatisation auto, Abs, Système de navigation / gps, Carnet d'entretien, Vitres éléctriques, Anti patinage, Esp, Volant sport                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |Dvd / cd / mp3, Jantes aluminium, Alarme, Airbags, Climatisation auto, Système de navigation / gps, Toit ouvrant, Détecteur de pluie, Ordinateur de bord, Radio commande au volant, Régulateur de vitesse, Affichage tête haute, Non fumeur                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |Dvd / cd / mp3, Alarme, Aide parking, Abs, Carnet d'entretien, Anti patinage, Capote électrique, Rétroviseur extérieur électrique, Intérieur cuir, Siége electrique, Vitres surteintées, Anti démarrage, Contrôle de pression des pneus, Direction assistée, Ordinateur de bord, Régulateur de vitesse, Affichage tête haute, Suspension sport, Frein de parking automatique, Non fumeur, Système d'identification du conducteur, Radar de recul, Limiteur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                    |
# |Jantes aluminium, Airbags, Climatisation auto, Vitres éléctriques, Esp, Toit ouvrant panoramique, Volant reglable, Volant sport, Radar de recul, Limiteur de vitesse, Verrouillage centralisé à distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# Column: first_owner
# +-----------+
# |first_owner|
# +-----------+
# |Oui        |
# |Non        |
# |NULL       |
# +-----------+
#
# Column: fiscal_power
# +------------+
# |fiscal_power|
# +------------+
# |31          |
# |34          |
# |28          |
# |27          |
# |26          |
# |12          |
# |22          |
# |13          |
# |6           |
# |16          |
# |3           |
# |20          |
# |40          |
# |5           |
# |19          |
# |41          |
# |15          |
# |37          |
# |9           |
# |17          |
# +------------+
# only showing top 20 rows
#
# Column: fuel_type
# +---------+
# |fuel_type|
# +---------+
# |hybride  |
# |essence  |
# |diesel   |
# +---------+
#
# Column: mileage
# +-------+
# |mileage|
# +-------+
# |135000 |
# |113000 |
# |109800 |
# |117500 |
# |78400  |
# |271000 |
# |85000  |
# |213000 |
# |16500  |
# |291000 |
# |450000 |
# |11500  |
# |870000 |
# |145000 |
# |132240 |
# |3000   |
# |345000 |
# |212000 |
# |90450  |
# |24664  |
# +-------+
# only showing top 20 rows
#
# Column: model
# +--------+
# |model   |
# +--------+
# |Expert  |
# |Astra   |
# |Maruti  |
# |Verso   |
# |Aygo    |
# |Mazda 6 |
# |Bertone |
# |C Max   |
# |Korando |
# |S-Presso|
# |Xj      |
# |S60     |
# |Viano   |
# |C6      |
# |124     |
# |307     |
# |Rifter  |
# |Evalia  |
# |205     |
# |Dokker  |
# +--------+
# only showing top 20 rows
#
# Column: origin
# +--------------------+
# |origin              |
# +--------------------+
# |Pas encore dédouanée|
# |Dédouanée           |
# |WW au Maroc         |
# |Importée neuve      |
# |NULL                |
# +--------------------+
#
# Column: price
# +-------+
# |price  |
# +-------+
# |113000 |
# |135000 |
# |419000 |
# |271000 |
# |85000  |
# |213000 |
# |450000 |
# |870000 |
# |11500  |
# |345000 |
# |145000 |
# |11800  |
# |88999  |
# |212000 |
# |1450000|
# |78000  |
# |610000 |
# |114000 |
# |190500 |
# |950000 |
# +-------+
# only showing top 20 rows
#
# Column: publication_date
# +----------------+
# |publication_date|
# +----------------+
# |12/04/2025 19:53|
# |12/04/2025 00:22|
# |12/04/2025 19:50|
# |12/04/2025 19:13|
# |12/04/2025 11:33|
# |12/04/2025 19:26|
# |12/04/2025 01:21|
# |31/03/2025 00:00|
# |12/01/2025 00:00|
# |12/04/2025 16:21|
# |11/04/2025 18:28|
# |12/04/2025 11:34|
# |14/03/2025 00:00|
# |11/04/2025 20:25|
# |29/03/2025 00:00|
# |11/04/2025 21:24|
# |12/04/2025 10:36|
# |12/04/2025 04:18|
# |27/03/2025 00:00|
# |12/04/2025 12:31|
# +----------------+
# only showing top 20 rows
#
# Column: sector
# +-------------------+
# |sector             |
# +-------------------+
# |Chichaoua          |
# |Targuist           |
# |Ben ahmed          |
# |Casablanca         |
# |Jorf El Melha      |
# |Agadir             |
# |Dakhla             |
# |Fnideq             |
# |Zemamra            |
# |Imzouren           |
# |Taza               |
# |Taounate           |
# |Tit Mellil         |
# |Gzenaya Al Janoubia|
# |Had Soualem        |
# |Lahraouyine        |
# |Fquih Ben Saleh    |
# |Tahannaout         |
# |Sabaa Aiyoun       |
# |Dar Bouazza        |
# +-------------------+
# only showing top 20 rows
#
# Column: seller_city
# +-------------------------+
# |seller_city              |
# +-------------------------+
# |Chichaoua                |
# |Ben ahmed                |
# |Les Cretes               |
# |Av Abdelkrim El Khattabi |
# |Ain Errouz               |
# |Abattoirs                |
# |Al Hana                  |
# |Derb Omar                |
# |Route de Lalla Takerkoust|
# |Hay Riyad                |
# |Casablanca               |
# |Abi Ragrag               |
# |Quartier Aérodrome       |
# |Targa                    |
# |Marjane 2                |
# |Hoda                     |
# |Touabel                  |
# |Dar Dbibagh              |
# |Hay Boudir               |
# |Agadir                   |
# +-------------------------+
# only showing top 20 rows
#
# Column: transmission
# +------------+
# |transmission|
# +------------+
# |Manuelle    |
# |Automatique |
# +------------+
#
# Column: year
# +----+
# |year|
# +----+
# |1959|
# |1990|
# |2025|
# |1975|
# |1977|
# |2003|
# |2007|
# |2018|
# |1974|
# |2015|
# |2023|
# |1955|
# |2006|
# |2022|
# |1978|
# |2013|
# |1956|
# |1997|
# |1988|
# |1994|
# +----+
# only showing top 20 rows

# %% [markdown]
# ### Statistics summary for numerical variables :

# %%
numerical_columns = [ 'fiscal_power' , 'price' , 'year' , 'door_count' , 'mileage' ]
data.describe(numerical_columns).toPandas()

# %% [markdown]
# ____________

# %% [markdown]
# # 5. Data preprocessing :

# %% [markdown]
# ### Check for missing values :

# %%
from pyspark.sql import functions as F

# Counting missing (null) values in each column
data.select([F.sum(F.col(c).isNull().cast("int")).alias(c) for c in data.columns]).toPandas()
# Out:
#    brand  condition  door_count  equipment  first_owner  fiscal_power  \
# 0   1506      26093        9159      20308        20575          2957
#
#    fuel_type  mileage  model  origin  price  publication_date  sector  \
# 0          0     3134   1506   28776  12674             23209       2
#
#    seller_city  transmission  year
# 0         1505             0  2806

# %% [markdown]
# ### Drop missing values :

# %%
# Drop all the missing values :
data_cleaned = data.dropna()

# %%
from pyspark.sql import functions as F

# Counting missing (null) values in each column
data_cleaned.select([F.sum(F.col(c).isNull().cast("int")).alias(c) for c in data_cleaned.columns]).toPandas()
# Out:
#    brand  condition  door_count  equipment  first_owner  fiscal_power  \
# 0      0          0           0          0            0             0
#
#    fuel_type  mileage  model  origin  price  publication_date  sector  \
# 0          0        0      0       0      0                 0       0
#
#    seller_city  transmission  year
# 0            0             0     0

# %%
# Data size (rows) before and after : 
print(f"Data size before droping missing values : {data.count()}")
print(f"Data size after droping missing values : {data_cleaned.count()}")
# Out:
# Data size before droping missing values : 60264
# Data size after droping missing values : 14416

# %% [markdown]
# ## Features ingineering :

# %% [markdown]
# ### Split data_publication column :

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType


data_cleaned = data_cleaned.withColumn("publication_date", F.to_timestamp("publication_date", "dd/MM/yyyy HH:mm"))

# Extract Year, Month, Day, Weekday, Is_Weekend, and Days_since_posted
data_features = data_cleaned.withColumn("publication_Year", F.year("publication_date")) \
       .withColumn("publication_Month", F.month("publication_date")) \
       .withColumn("publication_Day", F.dayofmonth("publication_date")) \
       .withColumn("publication_Weekday", F.dayofweek("publication_date")) \
       .withColumn("Is_Weekend", (F.dayofweek("publication_date") >= 6).cast(IntegerType())) \
       .withColumn("Days_since_posted", F.datediff(F.current_date(), "publication_date"))

# %%
# Show the result
data_features.select("publication_date", "publication_Year", "publication_Month", "publication_Day", "publication_Weekday", "Is_Weekend", "Days_since_posted").show(5)
# Out:
# +-------------------+----------------+-----------------+---------------+-------------------+----------+-----------------+
# |   publication_date|publication_Year|publication_Month|publication_Day|publication_Weekday|Is_Weekend|Days_since_posted|
# +-------------------+----------------+-----------------+---------------+-------------------+----------+-----------------+
# |2025-02-11 00:00:00|            2025|                2|             11|                  3|         0|               77|
# |2024-09-14 00:00:00|            2024|                9|             14|                  7|         1|              227|
# |2025-02-11 00:00:00|            2025|                2|             11|                  3|         0|               77|
# |2024-10-14 00:00:00|            2024|               10|             14|                  2|         0|              197|
# |2025-02-11 00:00:00|            2025|                2|             11|                  3|         0|               77|
# +-------------------+----------------+-----------------+---------------+-------------------+----------+-----------------+
# only showing top 5 rows

# %%
data_features.limit(5).toPandas()
# Out:
#         brand  condition  door_count  \
# 0  mitsubishi   Très bon           3
# 1  land rover  Excellent           5
# 2       dacia  Excellent           5
# 3        audi  Excellent           5
# 4  volkswagen  Excellent           5
#
#                                            equipment first_owner  \
# 0  Airbags, Caméra de recul, Climatisation, ESP, ...         Non
# 1  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...         Oui
# 2  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...         Oui
# 3  ABS, Airbags, CD/MP3/Bluetooth, Climatisation,...         Non
# 4  ABS, CD/MP3/Bluetooth, Caméra de recul, Climat...         Non
#
#    fiscal_power fuel_type  mileage      model       origin  ...      sector  \
# 0            11    diesel   274999     Pajero  WW au Maroc  ...      Agadir
# 1             8    diesel    22499  Discovery  WW au Maroc  ...      Agadir
# 2             6    diesel    72499     Duster  WW au Maroc  ...  Casablanca
# 3            11    diesel   184999         Q5  WW au Maroc  ...  Casablanca
# 4            12    diesel   274999    Touareg    Dédouanée  ...       Oujda
#
#       seller_city transmission  year publication_Year  publication_Month  \
# 0   Autre secteur     Manuelle  2007             2025                  2
# 1       Haut Anza  Automatique  2017             2024                  9
# 2  Sidi Bernoussi     Manuelle  2019             2025                  2
# 3       Ain Sebaa  Automatique  2010             2024                 10
# 4        Boustane  Automatique  2006             2025                  2
#
#    publication_Day  publication_Weekday  Is_Weekend  Days_since_posted
# 0               11                    3           0                 77
# 1               14                    7           1                227
# 2               11                    3           0                 77
# 3               14                    2           0                197
# 4               11                    3           0                 77
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Drop publication_date :

# %%
data_features = data_features.drop("publication_date")

# %% [markdown]
# ### Split equipments column :

# %%
data_features.select("equipment").limit(5).toPandas()
# Out:
#                                            equipment
# 0  Airbags, Caméra de recul, Climatisation, ESP, ...
# 1  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...
# 2  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...
# 3  ABS, Airbags, CD/MP3/Bluetooth, Climatisation,...
# 4  ABS, CD/MP3/Bluetooth, Caméra de recul, Climat...

# %%
# Declare different equipments types : 
equipment_types = [
    "aluminum_rims", "airbags", "air_conditioning", "navigation_system",
    "sunroof", "leather_seats", "parking_sensor", "rear_camera",
    "electric_windows", "abs", "esp", "cruise_control", 
    "speed_limiter", "cd_mp3_bluetooth", "onboard_computer", "central_locking"
]

# %%
from pyspark.sql.functions import col, when, lower, lit

def encode_equipment(df, equipment_col="equipment"):
    for eq in equipment_types:
        # Generate a clean column name
        new_col = eq.lower().replace(" ", "_").replace("/", "_").replace("-", "_")
        # Add column with True/False if the equipment exists
        df = df.withColumn(
            new_col,
            when(lower(col(equipment_col)).contains(eq.lower()), lit(True)).otherwise(lit(False))
        )
    return df

# %%
data_equipment = encode_equipment(data_features)

# %%
data_equipment.select("equipment", "airbags", "abs", "esp", "caméra_de_recul").show(5)
# Out:
# +--------------------+-------+-----+----+---------------+
# |           equipment|airbags|  abs| esp|caméra_de_recul|
# +--------------------+-------+-----+----+---------------+
# |Airbags, Caméra d...|   true|false|true|           true|
# |ABS, Airbags, CD/...|   true| true|true|           true|
# |ABS, Airbags, CD/...|   true| true|true|           true|
# |ABS, Airbags, CD/...|   true| true|true|          false|
# |ABS, CD/MP3/Bluet...|  false| true|true|           true|
# +--------------------+-------+-----+----+---------------+
# only showing top 5 rows

# %%
data_equipment.limit(6).toPandas()
# Out:
#         brand  condition  door_count  \
# 0  mitsubishi   Très bon           3
# 1  land rover  Excellent           5
# 2       dacia  Excellent           5
# 3        audi  Excellent           5
# 4  volkswagen  Excellent           5
# 5     peugeot  Excellent           5
#
#                                            equipment first_owner  \
# 0  Airbags, Caméra de recul, Climatisation, ESP, ...         Non
# 1  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...         Oui
# 2  ABS, Airbags, CD/MP3/Bluetooth, Caméra de recu...         Oui
# 3  ABS, Airbags, CD/MP3/Bluetooth, Climatisation,...         Non
# 4  ABS, CD/MP3/Bluetooth, Caméra de recul, Climat...         Non
# 5  ABS, Airbags, CD/MP3/Bluetooth, Climatisation,...         Non
#
#    fiscal_power fuel_type  mileage      model       origin  ...  \
# 0            11    diesel   274999     Pajero  WW au Maroc  ...
# 1             8    diesel    22499  Discovery  WW au Maroc  ...
# 2             6    diesel    72499     Duster  WW au Maroc  ...
# 3            11    diesel   184999         Q5  WW au Maroc  ...
# 4            12    diesel   274999    Touareg    Dédouanée  ...
# 5             6    diesel    62499        208  WW au Maroc  ...
#
#    radar_de_recul caméra_de_recul vitres_électriques    abs   esp  \
# 0            True            True               True  False  True
# 1            True            True               True   True  True
# 2            True            True               True   True  True
# 3            True           False               True   True  True
# 4            True            True               True   True  True
# 5            True           False               True   True  True
#
#    régulateur_de_vitesse  limiteur_de_vitesse  cd_mp3_bluetooth  \
# 0                  False                False             False
# 1                   True                 True              True
# 2                   True                 True              True
# 3                   True                 True              True
# 4                   True                 True              True
# 5                   True                 True              True
#
#    ordinateur_de_bord  verrouillage_centralisé
# 0                True                     True
# 1                True                     True
# 2                True                     True
# 3                True                     True
# 4                True                     True
# 5                True                     True
#
# [6 rows x 37 columns]

# %% [markdown]
# ###### Verification :

# %%
# Convert to Pandas DataFrame
pandas_df = data_equipment.toPandas()

# Save as CSV with Pandas
pandas_df.to_csv("verify_equipment1.csv", index=False)

# %% [markdown]
# #### Drop equipment column :

# %%
data_equipment = data_equipment.drop("equipment")

# %% [markdown]
# ### Data preprocessed 1 :

# %%
data_equipment.limit(5).toPandas()
# Out:
#         brand  condition  door_count first_owner  fiscal_power fuel_type  \
# 0  mitsubishi   Très bon           3         Non            11    diesel
# 1  land rover  Excellent           5         Oui             8    diesel
# 2       dacia  Excellent           5         Oui             6    diesel
# 3        audi  Excellent           5         Non            11    diesel
# 4  volkswagen  Excellent           5         Non            12    diesel
#
#    mileage      model       origin   price  ... radar_de_recul  \
# 0   274999     Pajero  WW au Maroc   85000  ...           True
# 1    22499  Discovery  WW au Maroc  190000  ...           True
# 2    72499     Duster  WW au Maroc  167000  ...           True
# 3   184999         Q5  WW au Maroc  120000  ...           True
# 4   274999    Touareg    Dédouanée   70000  ...           True
#
#   caméra_de_recul vitres_électriques    abs   esp  régulateur_de_vitesse  \
# 0            True               True  False  True                  False
# 1            True               True   True  True                   True
# 2            True               True   True  True                   True
# 3           False               True   True  True                   True
# 4            True               True   True  True                   True
#
#    limiteur_de_vitesse  cd_mp3_bluetooth  ordinateur_de_bord  \
# 0                False             False                True
# 1                 True              True                True
# 2                 True              True                True
# 3                 True              True                True
# 4                 True              True                True
#
#    verrouillage_centralisé
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
#
# [5 rows x 36 columns]

# %% [markdown]
# ##### save to csv :

# %%
# Save to csv : 
# Convert to Pandas DataFrame
pandas_df_df = data_equipment.toPandas()

# Save as CSV with Pandas
pandas_df_df.to_csv("data_preprocessed1.csv", index=False)

# %% [markdown]
# ## Variable encoding :

# %% [markdown]
# _______________

# %% [markdown]
# # 6. Model training :
